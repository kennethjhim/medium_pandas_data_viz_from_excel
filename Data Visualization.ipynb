# %%
import numpy as np
import altair as alt
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_can = pd.read_excel('data/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)

# %%
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can['Total'] = df_can.sum(axis=1)
df_can.set_index('Country', inplace=True)

# %%
years = list(range(1980, 2014))

# %%
df_CI = df_can.loc[['China', 'India'], years]

# %%
df_CI_wide = df_CI.T

# %%
df_CI_wide.plot(kind='bar', figsize=(10, 6))

# %%
df_CI_wide.plot(kind='area', stacked=False, figsize=(10, 6))

# %%
df_CI_wide.plot(kind='box', figsize=(8, 6))

# %%
count, bin_edges = np.histogram(df_CI_wide)

df_CI_wide.plot(kind='hist', figsize=(8, 5), xticks=bin_edges, alpha=0.6)

# %%
df_CI_wide.plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f652a1217844> in <module>
# ----> 1 df_CI_wide.plot(kind='scatter')
#
# ~\AppData\Roaming\Python\venv\vds\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\AppData\Roaming\Python\venv\vds\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#      62     plot_obj.draw()
#
# ~\AppData\Roaming\Python\venv\vds\lib\site-packages\pandas\plotting\_matplotlib\core.py in __init__(self, data, x, y, s, c, **kwargs)
#     934             # the handling of this argument later
#     935             s = 20
# --> 936         super().__init__(data, x, y, s=s, **kwargs)
#     937         if is_integer(c) and not self.data.columns.holds_integer():
#     938             c = self.data.columns[c]
#
# ~\AppData\Roaming\Python\venv\vds\lib\site-packages\pandas\plotting\_matplotlib\core.py in __init__(self, data, x, y, **kwargs)
#     865         MPLPlot.__init__(self, data, **kwargs)
#     866         if x is None or y is None:
# --> 867             raise ValueError(self._kind + " requires an x and y column")
#     868         if is_integer(x) and not self.data.columns.holds_integer():
#     869             x = self.data.columns[x]
#
# ValueError: scatter requires an x and y column

# %%
df_CI_long = df_CI_wide.reset_index().rename(columns={'index':'Year'}).melt(id_vars='Year', var_name='Country', value_name='Immigrants')

# %%
df_CI_long.head()
# Out:
#    Year Country  Immigrants
# 0  1980   China        5123
# 1  1981   China        6682
# 2  1982   China        3308
# 3  1983   China        1863
# 4  1984   China        1527

# %%
df_CI_long['Country']=pd.Categorical(df_CI_long['Country'])

col = df_CI_long['Country'].cat.codes.map({0:'b', 1:'r'})
df_CI_long.plot(kind='scatter', x='Year', y='Immigrants', figsize=(10, 6), c=col)

# %%
df_CI_long.plot(kind='scatter', x='Year', y='Immigrants', figsize=(10, 6))
